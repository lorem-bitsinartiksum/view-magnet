# %%
# %pip install tabula-py
# %pip install pandas

# %%
import tabula
from google.colab import files
uploaded = files.upload()

# %%
import os
os.mkdir("veriler-csv")
os.mkdir("veriler-json")
os.mkdir("veriler-json-edited")

# %%
import shutil
shutil.rmtree('veriler-csv')
shutil.rmtree('veriler-json')
shutil.rmtree('veriler-json-edited')

# %%
import os
pdf_path = "/content/ilce.pdf"
multi_tables = tabula.read_pdf(pdf_path, pages='all', multiple_tables=True, stream=True)
i=0
j=0
for table in multi_tables:
    if(i > 54 and i < 220):
      table.to_csv('veriler-csv/output'+str(j)+'.csv',index=False)
      #print(table)
      j=j+1
    i=i+1

# %%
import csv
import json

i=0
for filename in os.listdir("veriler-csv"):
  with open('veriler-csv/'+ filename) as f:
      reader = csv.DictReader(f)
      rows = list(reader)

  with open('veriler-json/'+ filename[:-3] +'json', 'w') as f:
      json.dump(rows, f)

  i=i+1

# %%
import json  
import pandas as pd  
from pandas.io.json import json_normalize  
import re
from pandas import DataFrame


for filename in os.listdir("veriler-json"):
  try:
    
    with open('/content/veriler-json/'+ filename) as f: 
        d = json.load(f)
        index=0
        cities=[]
        for x in d[index]:
          if d[index][str(x)] != "":
            cities.append(d[index][str(x)])
    
        index=index+1
        temp=[]
        nufus=[]
        while len(temp) !=  len(cities):
          for x in d[index]:
            s=d[index][str(x)]
            s=s.replace(" ", "")
            reg = re.search(r"\(([0-9]+)\)", s)
            if reg is not None:
              s=s.replace(("(" + reg .group(1) + ")"), "")
            reg2 = re.search(r"[0-9]+", s) 
            if reg2 is not None:
              temp.append(s)
          index =index + 1
        nufus=temp

        temp=[]
        sehirlesme_orani=[]
        while len(temp) !=  len(cities):
          for x in d[index]:
            s=d[index][str(x)]
            s=s.replace(" ", "")
            reg = re.search(r"\(([0-9]+)\)", s)
            if reg is not None:
              s=s.replace(("(" + reg .group(1) + ")"), "")
            reg2 = re.search(r"[0-9]+", s) 
            if reg2 is not None:
              temp.append(s)
          index=index + 1
        sehirlesme_orani=temp

        temp=[]
        nufus_artis_hizi=[]
        while len(temp) !=  len(cities):
          for x in d[index]:
            s=d[index][str(x)]
            s=s.replace(" ", "")
            reg = re.search(r"\(([0-9]+)\)", s)
            if reg is not None:
              s=s.replace(("(" + reg .group(1) + ")"), "")
            reg2 = re.search(r"[0-9]+", s) 
            if reg2 is not None:
              temp.append(s)
          index=index + 1
        nufus_artis_hizi=temp

        temp=[]
        nufus_yogunlugu=[]
        while len(temp) !=  len(cities):
          for x in d[index]:
            s=d[index][str(x)]
            s=s.replace(" ", "")
            reg = re.search(r"\(([0-9]+)\)", s)
            if reg is not None:
              s=s.replace(("(" + reg .group(1) + ")"), "")
            reg2 = re.search(r"[0-9]+", s) 
            if reg2 is not None:
              temp.append(s)
          index=index + 1
        nufus_yogunlugu=temp

        temp=[]
        nufus_bagimlilik_orani=[]
        while len(temp) !=  len(cities):
          for x in d[index]:
            s=d[index][str(x)]
            s=s.replace(" ", "")
            reg = re.search(r"\(([0-9]+)\)", s)
            if reg is not None:
              s=s.replace(("(" + reg .group(1) + ")"), "")
            reg2 = re.search(r"[0-9]+", s) 
            if reg2 is not None:
              temp.append(s)
          index =index + 1
        nufus_bagimlilik_orani=temp

        temp=[]
        ortalama_hanehalki_buyuklugu=[]
        while len(temp) !=  len(cities):
          for x in d[index]:
            s=d[index][str(x)]
            s=s.replace(" ", "")
            reg = re.search(r"\(([0-9]+)\)", s)
            if reg is not None:
              s=s.replace(("(" + reg .group(1) + ")"), "")
            reg2 = re.search(r"[0-9]+", s) 
            if reg2 is not None:
              temp.append(s)
          index =index + 1
        ortalama_hanehalki_buyuklugu=temp

        temp=[]
        tarim_sektorunde_calisma_orani=[]
        while len(temp) !=  len(cities):
          for x in d[index]:
            s=d[index][str(x)]
            s=s.replace(" ", "")
            reg = re.search(r"\(([0-9]+)\)", s)
            if reg is not None:
              s=s.replace(("(" + reg .group(1) + ")"), "")
            reg2 = re.search(r"[0-9]+", s) 
            if reg2 is not None:
              temp.append(s)
          index =index + 1
        tarim_sektorunde_calisma_orani=temp

        temp=[]
        sanayi_sektorunde_calisma_orani=[]
        while len(temp) !=  len(cities):
          for x in d[index]:
            s=d[index][str(x)]
            s=s.replace(" ", "")
            reg = re.search(r"\(([0-9]+)\)", s)
            if reg is not None:
              s=s.replace(("(" + reg .group(1) + ")"), "")
            reg2 = re.search(r"[0-9]+", s) 
            if reg2 is not None:
              temp.append(s)
          index =index + 1
        sanayi_sektorunde_calisma_orani=temp

        temp=[]
        hizmetler_sektorunde_calisma_orani=[]
        while len(temp) !=  len(cities):
          for x in d[index]:
            s=d[index][str(x)]
            s=s.replace(" ", "")
            reg = re.search(r"\(([0-9]+)\)", s)
            if reg is not None:
              s=s.replace(("(" + reg .group(1) + ")"), "")
            reg2 = re.search(r"[0-9]+", s) 
            if reg2 is not None:
              temp.append(s)
          index =index + 1
        hizmetler_sektorunde_calisma_orani=temp

        temp=[]
        issizlik_orani=[]
        while len(temp) !=  len(cities):
          for x in d[index]:
            s=d[index][str(x)]
            s=s.replace(" ", "")
            reg = re.search(r"\(([0-9]+)\)", s)
            if reg is not None:
              s=s.replace(("(" + reg .group(1) + ")"), "")
            reg2 = re.search(r"[0-9]+", s) 
            if reg2 is not None:
              temp.append(s)
          index =index + 1
        issizlik_orani=temp

        temp=[]
        okur_yazar_orani=[]
        while len(temp) !=  len(cities):
          for x in d[index]:
            s=d[index][str(x)]
            s=s.replace(" ", "")
            reg = re.search(r"\(([0-9]+)\)", s)
            if reg is not None:
              s=s.replace(("(" + reg .group(1) + ")"), "")
            reg2 = re.search(r"[0-9]+", s) 
            if reg2 is not None:
              temp.append(s)
          index =index + 1
        okur_yazar_orani=temp

        temp=[]
        bebek_olum_orani=[]
        while len(temp) !=  len(cities):
          for x in d[index]:
            s=d[index][str(x)]
            s=s.replace(" ", "")
            reg = re.search(r"\(([0-9]+)\)", s)
            if reg is not None:
              s=s.replace(("(" + reg .group(1) + ")"), "")
            reg2 = re.search(r"[0-9]+", s) 
            if reg2 is not None:
              temp.append(s)
          index =index + 1
        bebek_olum_orani=temp

        temp=[]
        fert_basina_genel_butce_geliri=[]
        while len(temp) !=  len(cities):
          for x in d[index]:
            s=d[index][str(x)]
            s=s.replace(" ", "")
            reg = re.search(r"\(([0-9]+)\)", s)
            if reg is not None:
              s=s.replace(("(" + reg .group(1) + ")"), "")
            reg2 = re.search(r"[0-9]+", s) 
            if reg2 is not None:
              temp.append(s)
          index =index + 1
        fert_basina_genel_butce_geliri=temp

        temp=[]
        vergi_gelirlerinin_ulke_icindeki_payi=[]
        while len(temp) !=  len(cities):
          for x in d[index]:
            s=d[index][str(x)]
            s=s.replace(" ", "")
            reg = re.search(r"\(([0-9]+)\)", s)
            if reg is not None:
              s=s.replace(("(" + reg .group(1) + ")"), "")
            reg2 = re.search(r"[0-9]+", s) 
            if reg2 is not None:
              temp.append(s)
          index =index + 1
        vergi_gelirlerinin_ulke_icindeki_payi=temp

        temp=[]
        tarimsal_uretimin_ulke_icindeki_payi=[]
        while len(temp) !=  len(cities):
          for x in d[index]:
            s=d[index][str(x)]
            s=s.replace(" ", "")
            reg = re.search(r"\(([0-9]+)\)", s)
            if reg is not None:
              s=s.replace(("(" + reg .group(1) + ")"), "")
            reg2 = re.search(r"[0-9]+", s) 
            if reg2 is not None:
              temp.append(s)
          index =index + 1
        tarimsal_uretimin_ulke_icindeki_payi=temp

        data = dict()
        for x in range(len(nufus)):
          elem = [ nufus[x],sehirlesme_orani[x],nufus_artis_hizi[x],nufus_yogunlugu[x],nufus_bagimlilik_orani[x],ortalama_hanehalki_buyuklugu[x],tarim_sektorunde_calisma_orani[x], sanayi_sektorunde_calisma_orani[x],hizmetler_sektorunde_calisma_orani[x],issizlik_orani[x],okur_yazar_orani[x],bebek_olum_orani[x],fert_basina_genel_butce_geliri[x], vergi_gelirlerinin_ulke_icindeki_payi[x],tarimsal_uretimin_ulke_icindeki_payi[x] ]
          data[cities[x]] = elem 

        df = pd.DataFrame.from_dict(data)
        df.index = [ "nufus","sehirlesme_orani","nufus_artis_hizi","nufus_yogunlugu","nufus_bagimlilik_orani","ortalama_hanehalki_buyuklugu", "tarim_sektorunde_calisma_orani", "sanayi_sektorunde_calisma_orani", "hizmetler_sektorunde_calisma_orani", "issizlik_orani", "okur_yazar_orani", "bebek_olum_orani", "fert_basina_genel_butce_geliri", "vergi_gelirlerinin_ulke_icindeki_payi", "tarimsal_uretimin_ulke_icindeki_payi" ]

        df.to_json(r'veriler-json-edited/' + filename)
        
  except:
    print(filename)

# %%
import json  
import pandas as pd  
from pandas.io.json import json_normalize  
import re
from pandas import DataFrame


with open('/content/veriler-json/'+ "output92.json") as f: 
    d = json.load(f)
    index=0
    cities=[]
    for x in d[index]:
      if d[index][str(x)] != "":
        cities.append(d[index][str(x)])

    index=index+1
    temp=[]
    nufus=[]
    while len(temp) !=  len(cities):
      for x in d[index]:
        s=d[index][str(x)]
        s=s.replace(" ", "")
        reg = re.search(r"\(([0-9]+)\)", s)
        if reg is not None:
          s=s.replace(("(" + reg .group(1) + ")"), "")
        reg2 = re.search(r"[0-9]+", s) 
        if reg2 is not None:
          temp.append(s)
      index =index + 1
    nufus=temp

    temp=[]
    sehirlesme_orani=[]
    while len(temp) !=  len(cities):
      for x in d[index]:
        s=d[index][str(x)]
        s=s.replace(" ", "")
        reg = re.search(r"\(([0-9]+)\)", s)
        if reg is not None:
          s=s.replace(("(" + reg .group(1) + ")"), "")
        reg2 = re.search(r"[0-9]+", s) 
        if reg2 is not None:
          temp.append(s)
      index=index + 1
    sehirlesme_orani=temp

    temp=[]
    nufus_artis_hizi=[]
    while len(temp) !=  len(cities):
      for x in d[index]:
        s=d[index][str(x)]
        s=s.replace(" ", "")
        reg = re.search(r"\(([0-9]+)\)", s)
        if reg is not None:
          s=s.replace(("(" + reg .group(1) + ")"), "")
        reg2 = re.search(r"[0-9]+", s) 
        if reg2 is not None:
          temp.append(s)
      index=index + 1
    nufus_artis_hizi=temp

    temp=[]
    nufus_yogunlugu=[]
    while len(temp) !=  len(cities):
      for x in d[index]:
        s=d[index][str(x)]
        s=s.replace(" ", "")
        reg = re.search(r"\(([0-9]+)\)", s)
        if reg is not None:
          s=s.replace(("(" + reg .group(1) + ")"), "")
        reg2 = re.search(r"[0-9]+", s) 
        if reg2 is not None:
          temp.append(s)
      index=index + 1
    nufus_yogunlugu=temp

    temp=[]
    nufus_bagimlilik_orani=[]
    while len(temp) !=  len(cities):
      for x in d[index]:
        s=d[index][str(x)]
        s=s.replace(" ", "")
        reg = re.search(r"\(([0-9]+)\)", s)
        if reg is not None:
          s=s.replace(("(" + reg .group(1) + ")"), "")
        reg2 = re.search(r"[0-9]+", s) 
        if reg2 is not None:
          temp.append(s)
      index =index + 1
    nufus_bagimlilik_orani=temp

    temp=[]
    ortalama_hanehalki_buyuklugu=[]
    while len(temp) !=  len(cities):
      for x in d[index]:
        s=d[index][str(x)]
        s=s.replace(" ", "")
        reg = re.search(r"\(([0-9]+)\)", s)
        if reg is not None:
          s=s.replace(("(" + reg .group(1) + ")"), "")
        reg2 = re.search(r"[0-9]+", s) 
        if reg2 is not None:
          temp.append(s)
      index =index + 1
    ortalama_hanehalki_buyuklugu=temp

    temp=[]
    tarim_sektorunde_calisma_orani=[]
    while len(temp) !=  len(cities):
      for x in d[index]:
        s=d[index][str(x)]
        s=s.replace(" ", "")
        reg = re.search(r"\(([0-9]+)\)", s)
        if reg is not None:
          s=s.replace(("(" + reg .group(1) + ")"), "")
        reg2 = re.search(r"[0-9]+", s) 
        if reg2 is not None:
          temp.append(s)
      index =index + 1
    tarim_sektorunde_calisma_orani=temp

    temp=[]
    sanayi_sektorunde_calisma_orani=[]
    while len(temp) !=  len(cities):
      for x in d[index]:
        s=d[index][str(x)]
        s=s.replace(" ", "")
        reg = re.search(r"\(([0-9]+)\)", s)
        if reg is not None:
          s=s.replace(("(" + reg .group(1) + ")"), "")
        reg2 = re.search(r"[0-9]+", s) 
        if reg2 is not None:
          temp.append(s)
      index =index + 1
    sanayi_sektorunde_calisma_orani=temp

    temp=[]
    hizmetler_sektorunde_calisma_orani=[]
    while len(temp) !=  len(cities):
      for x in d[index]:
        s=d[index][str(x)]
        s=s.replace(" ", "")
        reg = re.search(r"\(([0-9]+)\)", s)
        if reg is not None:
          s=s.replace(("(" + reg .group(1) + ")"), "")
        reg2 = re.search(r"[0-9]+", s) 
        if reg2 is not None:
          temp.append(s)
      index =index + 1
    hizmetler_sektorunde_calisma_orani=temp

    temp=[]
    issizlik_orani=[]
    while len(temp) !=  len(cities):
      for x in d[index]:
        s=d[index][str(x)]
        s=s.replace(" ", "")
        reg = re.search(r"\(([0-9]+)\)", s)
        if reg is not None:
          s=s.replace(("(" + reg .group(1) + ")"), "")
        reg2 = re.search(r"[0-9]+", s) 
        if reg2 is not None:
          temp.append(s)
      index =index + 1
    issizlik_orani=temp

    temp=[]
    okur_yazar_orani=[]
    while len(temp) !=  len(cities):
      for x in d[index]:
        s=d[index][str(x)]
        s=s.replace(" ", "")
        reg = re.search(r"\(([0-9]+)\)", s)
        if reg is not None:
          s=s.replace(("(" + reg .group(1) + ")"), "")
        reg2 = re.search(r"[0-9]+", s) 
        if reg2 is not None:
          temp.append(s)
      index =index + 1
    okur_yazar_orani=temp

    temp=[]
    bebek_olum_orani=[]
    while len(temp) !=  len(cities):
      for x in d[index]:
        s=d[index][str(x)]
        s=s.replace(" ", "")
        reg = re.search(r"\(([0-9]+)\)", s)
        if reg is not None:
          s=s.replace(("(" + reg .group(1) + ")"), "")
        reg2 = re.search(r"[0-9]+", s) 
        if reg2 is not None:
          temp.append(s)
      index =index + 1
    bebek_olum_orani=temp

    index =index + 1
    temp=[]
    fert_basina_genel_butce_geliri=[]
    while len(temp) !=  len(cities):
      for x in d[index]:
        s=d[index][str(x)]
        s=s.replace(" ", "")
        reg = re.search(r"\(([0-9]+)\)", s)
        if reg is not None:
          s=s.replace(("(" + reg .group(1) + ")"), "")
        reg2 = re.search(r"[0-9]+", s) 
        if reg2 is not None:
          temp.append(s)
      index =index + 1
    fert_basina_genel_butce_geliri=temp

    temp=[]
    vergi_gelirlerinin_ulke_icindeki_payi=[]
    while len(temp) !=  len(cities):
      for x in d[index]:
        s=d[index][str(x)]
        s=s.replace(" ", "")
        reg = re.search(r"\(([0-9]+)\)", s)
        if reg is not None:
          s=s.replace(("(" + reg .group(1) + ")"), "")
        reg2 = re.search(r"[0-9]+", s) 
        if reg2 is not None:
          temp.append(s)
      index =index + 1
    vergi_gelirlerinin_ulke_icindeki_payi=temp

    temp=[]
    tarimsal_uretimin_ulke_icindeki_payi=[]
    while len(temp) !=  len(cities):
      for x in d[index]:
        s=d[index][str(x)]
        s=s.replace(" ", "")
        reg = re.search(r"\(([0-9]+)\)", s)
        if reg is not None:
          s=s.replace(("(" + reg .group(1) + ")"), "")
        reg2 = re.search(r"[0-9]+", s) 
        if reg2 is not None:
          temp.append(s)
      index =index + 1
    tarimsal_uretimin_ulke_icindeki_payi=temp

    data = dict()
    for x in range(len(nufus)):
      elem = [ nufus[x],sehirlesme_orani[x],nufus_artis_hizi[x],nufus_yogunlugu[x],nufus_bagimlilik_orani[x],ortalama_hanehalki_buyuklugu[x],tarim_sektorunde_calisma_orani[x], sanayi_sektorunde_calisma_orani[x],hizmetler_sektorunde_calisma_orani[x],issizlik_orani[x],okur_yazar_orani[x],bebek_olum_orani[x],fert_basina_genel_butce_geliri[x], vergi_gelirlerinin_ulke_icindeki_payi[x],tarimsal_uretimin_ulke_icindeki_payi[x] ]
      data[cities[x]] = elem 

    df = pd.DataFrame.from_dict(data)
    df.index = [ "nufus","sehirlesme_orani","nufus_artis_hizi","nufus_yogunlugu","nufus_bagimlilik_orani","ortalama_hanehalki_buyuklugu", "tarim_sektorunde_calisma_orani", "sanayi_sektorunde_calisma_orani", "hizmetler_sektorunde_calisma_orani", "issizlik_orani", "okur_yazar_orani", "bebek_olum_orani", "fert_basina_genel_butce_geliri", "vergi_gelirlerinin_ulke_icindeki_payi", "tarimsal_uretimin_ulke_icindeki_payi" ]

    df.to_json(r'veriler-json-edited/' + "output92.json")
